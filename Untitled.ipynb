# %%
import requests

# url = 'https://data.worldbank.org/indicator/SI.POV.DDAY' 
# response = requests.get(url, params={'downloadformat': 'csv'})
url = 'https://data.worldbank.org/indicator/SI.POV.DDAY'
response = requests.get(url)

print(response.headers)
# Out:
# {'Server': 'nginx', 'Date': 'Fri, 08 Mar 2019 10:43:57 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'X-Powered-By': 'Express', 'X-XSS-Protection': '1', 'ETag': 'W/"c2e5b-5NsBN9growqvM2ZoTTiYcg"', 'Vary': 'Accept-Encoding', 'Content-Encoding': 'gzip', 'X-Frame-Options': 'DENY', 'X-Proxy-Cache': 'MISS', 'X-Source': 'prod-web2.localdomain.localdomain'}

# %%
# !pip3 install requests
# Out:
# Requirement already satisfied: requests in c:\users\bruger\appdata\local\programs\python\python37-32\lib\site-packages (2.21.0)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\bruger\appdata\local\programs\python\python37-32\lib\site-packages (from requests) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bruger\appdata\local\programs\python\python37-32\lib\site-packages (from requests) (2018.11.29)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\bruger\appdata\local\programs\python\python37-32\lib\site-packages (from requests) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\bruger\appdata\local\programs\python\python37-32\lib\site-packages (from requests) (1.24.1)
# You are using pip version 18.1, however version 19.0.3 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import requests

# url = 'https://data.worldbank.org/indicator/SI.POV.DDAY' 
# response = requests.get(url, params={'downloadformat': 'csv'})
url = 'https://data.worldbank.org/indicator/SI.POV.DDAY?downloadformat=csv'
response = requests.get(url)

print(response.headers)
# Out:
# {'Server': 'nginx', 'Date': 'Fri, 08 Mar 2019 11:00:05 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'X-Powered-By': 'Express', 'X-XSS-Protection': '1', 'ETag': 'W/"c2f5e-BBUwPa2tOFo8LjE5F9en7A"', 'Vary': 'Accept-Encoding', 'Content-Encoding': 'gzip', 'X-Frame-Options': 'DENY', 'X-Proxy-Cache': 'MISS', 'X-Source': 'prod-web2.localdomain.localdomain'}

# %%
fname = response.headers['Content-Disposition'].split('=')[1]

if response.ok:  # status_code == 200:
    with open(fname, 'wb') as f:
        f.write(response.content)  
print('Downloaded {}'.format(fname))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-030a419cd2d8> in <module>()
# ----> 1 fname = response.headers['Content-Disposition'].split('=')[1]
#       2
#       3 if response.ok:  # status_code == 200:
#       4     with open(fname, 'wb') as f:
#       5         f.write(response.content)
#
# ~\Anaconda3\lib\site-packages\requests\structures.py in __getitem__(self, key)
#      52
#      53     def __getitem__(self, key):
# ---> 54         return self._store[key.lower()][1]
#      55
#      56     def __delitem__(self, key):
#
# KeyError: 'content-disposition'

# %%
#%% hele cellen skriver i cmd (terminal) ls lister piper over i tail

# %%
# %%bash
# ls -ltrh | tail
# #man ls
# Out:
# total 28K
# -rw-r--r-- 1 bruger 197121 7,1K mar  8 12:01 Untitled.ipynb
# -rw-r--r-- 1 bruger 197121  18K mar  8 12:03 API_SI.POV.DDAY_DS2_en_csv_v2_10474275.zip

# %%
import zipfile

zipfile.ZipFile(fname, 'r').extractall('.')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-3bb6f55e96a1> in <module>()
#       1 import zipfile
#       2
# ----> 3 zipfile.ZipFile(fname, 'r').extractall('.')
#
# NameError: name 'fname' is not defined

# %%
# %%bash
#
# ls -ltrh | tail
# Out:
# total 156K
# -rw-r--r-- 1 bruger 197121  818 feb 11 13:15 Metadata_Indicator_API_SI.POV.DDAY_DS2_en_csv_v2_10474275.csv
# -rw-r--r-- 1 bruger 197121  40K feb 11 13:15 Metadata_Country_API_SI.POV.DDAY_DS2_en_csv_v2_10474275.csv
# -rw-r--r-- 1 bruger 197121  79K feb 11 13:15 API_SI.POV.DDAY_DS2_en_csv_v2_10474275.csv
# -rw-r--r-- 1 bruger 197121  18K mar  8 12:03 API_SI.POV.DDAY_DS2_en_csv_v2_10474275.zip
# -rw-r--r-- 1 bruger 197121 9,4K mar  8 12:07 Untitled.ipynb

# %%
from glob import glob
# glob is useful in any situation where your program needs to look for a list of files on the filesystem with names matching a pattern. If you need a list of filenames that all have a certain extension, prefix, or any common string in the middle, use glob instead of writing code to scan the directory contents yourself.

local_file = glob('./*API_SI*.csv')[0]
local_file
# Out:
# '.\\API_SI.POV.DDAY_DS2_en_csv_v2_10474275.csv'

# %%
# %%bash
# head ./*API_SI*.csv
# Out:
# ==> ./API_SI.POV.DDAY_DS2_en_csv_v2_10474275.csv <==
# ï»¿"Data Source","World Development Indicators",
#
# "Last Updated Date","2019-01-30",
#
# "Country Name","Country Code","Indicator Name","Indicator Code","1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018",
# "Aruba","ABW","Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)","SI.POV.DDAY","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","",
# "Afghanistan","AFG","Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)","SI.POV.DDAY","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","",
# "Angola","AGO","Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)","SI.POV.DDAY","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","32.3","","","","","","","","30.1","","","","","","","","","","",
# "Albania","ALB","Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)","SI.POV.DDAY","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","1.1","","","","","","2","","","1.1","","","0.4","","","","1.1","","","","","","",
# "Andorra","AND","Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)","SI.POV.DDAY","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","",
#
# ==> ./Metadata_Country_API_SI.POV.DDAY_DS2_en_csv_v2_10474275.csv <==
# ï»¿"Country Code","Region","IncomeGroup","SpecialNotes","TableName",
# "ABW","Latin America & Caribbean","High income","Mining is included in agriculture
# Electricty and gas includes manufactures of refined petroleoum products","Aruba",
# "AFG","South Asia","Low income","Fiscal year end: March 20; reporting period for national accounts data is calendar year, estimated to insure consistency between national accounts and fiscal data. National accounts data are sourced from the IMF and differ from the Central Statistics Organization numbers due to exclusion of the opium economy.","Afghanistan",
# "AGO","Sub-Saharan Africa","Lower middle income","","Angola",
# "ALB","Europe & Central Asia","Upper middle income","","Albania",
# "AND","Europe & Central Asia","High income","WB-3 code changed from ADO to AND to align with ISO code.","Andorra",
# "ARB","","","Arab World aggregate. Arab World is composed of members of the League of Arab States.","Arab World",
# "ARE","Middle East & North Africa","High income","","United Arab Emirates",
# "ARG","Latin America & Caribbean","High income","Series of GNI and GNDI from 1993-2017 have been updated due to new data available
#
# ==> ./Metadata_Indicator_API_SI.POV.DDAY_DS2_en_csv_v2_10474275.csv <==
# ï»¿"INDICATOR_CODE","INDICATOR_NAME","SOURCE_NOTE","SOURCE_ORGANIZATION",
# "SI.POV.DDAY","Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)","Poverty headcount ratio at $1.90 a day is the percentage of the population living on less than $1.90 a day at 2011 international prices. As a result of revisions in PPP exchange rates, poverty rates for individual countries cannot be compared with poverty rates reported in earlier editions.","World Bank, Development Research Group. Data are based on primary household survey data obtained from government statistical agencies and World Bank country departments. Data for high-income economies are from the Luxembourg Income Study database. For more information and methodology, please see PovcalNet (http://iresearch.worldbank.org/PovcalNet/index.htm).",

# %%
# %%bash
# # sed is a cli application that can filter text from pipeline (inputstream or a file)
# # Sed Linux command doesn’t update your data. It only sends the changed text to STDOUT
# # To know more about the sed tool: https://www.geeksforgeeks.org/sed-command-in-linux-unix-with-examples/
# sed '5!d' API_SI.POV.DDAY_DS2_en_csv_v2_10474275.csv  # sed delete all lines except line 5 (sed '5d'
# Out:
# "Country Name","Country Code","Indicator Name","Indicator Code","1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018",

# %%
import subprocess

# %%
cmd = 'sed 5!d {}'.format(local_file).split()
out, err = subprocess.Popen(cmd, stdout=subprocess.PIPE, 
                            stderr=subprocess.STDOUT).communicate()

# %%
# Since we are getting the output as a byte literal, we have to decode it into string
header_cols = out.splitlines()[0].decode('UTF-8').split(',')
header_cols = [h.replace('"', '') for h in header_cols]
print(header_cols)
# Out:
# ['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '']

# %%
# %%bash
# ls -ltr *.csv
# Out:
# -rw-r--r-- 1 bruger 197121   818 feb 11 13:15 Metadata_Indicator_API_SI.POV.DDAY_DS2_en_csv_v2_10474275.csv
# -rw-r--r-- 1 bruger 197121 39996 feb 11 13:15 Metadata_Country_API_SI.POV.DDAY_DS2_en_csv_v2_10474275.csv
# -rw-r--r-- 1 bruger 197121 80390 feb 11 13:15 API_SI.POV.DDAY_DS2_en_csv_v2_10474275.csv

# %%
import subprocess

# %%
local_file
# Out:
# '.\\API_SI.POV.DDAY_DS2_en_csv_v2_10474275.csv'

# %%
cmd = ['grep', '-E', 'ARG|CIV|USA', local_file]
out, err = subprocess.Popen(cmd, stdout=subprocess.PIPE, 
                            stderr=subprocess.STDOUT).communicate()

# %%
lines = out.decode('UTF-8').splitlines()
lines = [l.split(',') for l in lines]
lines = [[c.replace('"', '') for c in l] for l in lines]
lines
# Out:
# [['Argentina',
#   'ARG',
#   'Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)',
#   'SI.POV.DDAY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0.4',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0',
#   '0',
#   '',
#   '',
#   '',
#   '1.1',
#   '2.1',
#   '2.4',
#   '2.3',
#   '4.1',
#   '4.6',
#   '4.1',
#   '4.6',
#   '4.8',
#   '5.7',
#   '9.4',
#   '14',
#   '7',
#   '5.4',
#   '3.9',
#   '3.3',
#   '2.9',
#   '2.6',
#   '2.6',
#   '1.1',
#   '0.9',
#   '0.8',
#   '0.8',
#   '0.7',
#   '',
#   '0.6',
#   '',
#   '',
#   ''],
#  ["Cote d'Ivoire",
#   'CIV',
#   'Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)',
#   'SI.POV.DDAY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '6.8',
#   '3.1',
#   '6.8',
#   '10.7',
#   '',
#   '',
#   '',
#   '22.4',
#   '',
#   '',
#   '19.6',
#   '',
#   '',
#   '25.8',
#   '',
#   '',
#   '',
#   '23.2',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '29.1',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '28.2',
#   '',
#   '',
#   '',
#   ''],
#  ['United States',
#   'USA',
#   'Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)',
#   'SI.POV.DDAY',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '',
#   '',
#   '0.5',
#   '',
#   '',
#   '0.7',
#   '',
#   '',
#   '0.7',
#   '',
#   '',
#   '0.7',
#   '',
#   '',
#   '',
#   '1',
#   '',
#   '',
#   '1',
#   '',
#   '',
#   '1',
#   '',
#   '',
#   '1',
#   '',
#   '',
#   '1.2',
#   '',
#   '',
#   '']]

# %%
print(header_cols)
print(lines)
# Out:
# ['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '']
# [['Argentina', 'ARG', 'Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)', 'SI.POV.DDAY', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '0.4', '', '', '', '', '', '0', '0', '', '', '', '1.1', '2.1', '2.4', '2.3', '4.1', '4.6', '4.1', '4.6', '4.8', '5.7', '9.4', '14', '7', '5.4', '3.9', '3.3', '2.9', '2.6', '2.6', '1.1', '0.9', '0.8', '0.8', '0.7', '', '0.6', '', '', ''], ["Cote d'Ivoire", 'CIV', 'Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)', 'SI.POV.DDAY', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '6.8', '3.1', '6.8', '10.7', '', '', '', '22.4', '', '', '19.6', '', '', '25.8', '', '', '', '23.2', '', '', '', '', '', '29.1', '', '', '', '', '', '', '28.2', '', '', '', ''], ['United States', 'USA', 'Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)', 'SI.POV.DDAY', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '0.5', '', '', '', '', '', '', '0.5', '', '', '', '', '0.5', '', '', '0.7', '', '', '0.7', '', '', '0.7', '', '', '', '1', '', '', '1', '', '', '1', '', '', '1', '', '', '1.2', '', '', '']]

# %%
import pandas as pd
import numpy as np
# %matplotlib notebook

# %%
# reference to check graph: https://www.klimadebat.dk/grafer_co2udledning.php
header_cols[4:-1]
lines[0][4:-1]

ts_arg = pd.Series(lines[0][4:-1], index=np.asarray(header_cols[4:-1], dtype=int))
ts_arg = pd.to_numeric(ts_arg)
ts_arg.loc[1960]
# Out:
# nan

# %%
ts_arg.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ts_civ = pd.Series(lines[1][4:-1], index=np.asarray(header_cols[4:-1], dtype=int))
ts_civ = pd.to_numeric(ts_civ)
ts_civ.plot()

# %%
ts_usa = pd.Series(lines[1][4:-1], index=np.asarray(header_cols[4:-1], dtype=int))
ts_usa = pd.to_numeric(ts_usa)
ts_usa.plot()
ts_civ.plot()
ts_arg.plot()

# %%
ts = pd.concat([ts_arg, ts_civ, ts_usa], axis=1, keys=['ARG', 'CIV', 'USA']) # axis=0 is default (concats like sql UNION) axis=1 concats the data along the x axis

ts.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import pandas as pd

expenditure_csv = 
expenditures = pd.read_csv(expenditure_csv, skiprows=4)
expenditures
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-58a4912f746a> in <module>()
#       2
#       3
# ----> 4 expenditures = pd.read_csv(expenditure_csv, skiprows=4)
#       5 expenditures
#
# NameError: name 'expenditure_csv' is not defined

# %%
import pandas as pd


expenditures = pd.read_csv(expenditure_csv, skiprows=4)
expenditures
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-58a4912f746a> in <module>()
#       2
#       3
# ----> 4 expenditures = pd.read_csv(expenditure_csv, skiprows=4)
#       5 expenditures
#
# NameError: name 'expenditure_csv' is not defined
